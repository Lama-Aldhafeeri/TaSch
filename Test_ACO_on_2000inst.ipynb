# %% [markdown]
# Fetch Dataset

# %%
import os
import zipfile
import requests

# Define the GitHub raw file URL
zip_url = "https://github.com/Lama-Aldhafeeri/TaSch/raw/main/task_machine_datasets_2000_tasks_variable.zip"

# Download the zip file
zip_path = "task_machine_datasets_2000.zip"
response = requests.get(zip_url)
with open(zip_path, "wb") as file:
    file.write(response.content)

# Extract the zip file
dataset_path = "dataset"
os.makedirs(dataset_path, exist_ok=True)

with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(dataset_path)

# Verify extraction
dataset_files = sorted(os.listdir(dataset_path))
print(f"Extracted {len(dataset_files)} dataset files!")
print(f"Example file: {dataset_files[:5]}")
# Out:
# Extracted 2000 dataset files!
# Example file: ['instance_10_100_10_1.txt', 'instance_10_100_10_10.txt', 'instance_10_100_10_11.txt', 'instance_10_100_10_12.txt', 'instance_10_100_10_13.txt']

# %% [markdown]
# Load Dataset Files

# %%
import os
import numpy as np
import pandas as pd

def read_data(file_path):
    """Reads benchmark data from a given file."""
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Parse tasks
    tasks = list(map(int, lines[0].strip().split()))

    # Parse virtual machines
    vms = list(map(int, lines[1].strip().split()))

    # Parse execution times
    times = {}
    for entry in lines[2:]:
        task, vm, time = map(int, entry.strip().strip("()").split(","))
        times[(task, vm)] = time
    return tasks, vms, times


# Verify dataset loading
print(f"Loaded {len(dataset_files)} dataset files!")
print(f"Example file: {dataset_files[0]}")
# Out:
# Loaded 2000 dataset files!
# Example file: instance_10_100_10_1.txt

# %% [markdown]
# Setup compute imbalance factor

# %%
def compute_degree_of_imbalance(vm_loads):
    """Compute Degree of Imbalance (DI) as per Eq. (8)."""
    T_max = np.max(vm_loads)  # Maximum execution time among VMs
    T_min = np.min(vm_loads)  # Minimum execution time among VMs
    T_avg = np.mean(vm_loads)  # Average execution time among VMs

    if T_avg == 0:
        return 0  # Avoid division by zero

    DI = (T_max + T_min) / T_avg
    return DI

# %% [markdown]
# Define the ACO

# %%
import numpy as np

class AntColonyOptimization:
    def __init__(self, num_ants, num_iterations, alpha, beta, rho, Q):
        self.num_ants = num_ants
        self.num_iterations = num_iterations
        self.alpha = alpha
        self.beta = beta
        self.rho = rho  # Evaporation rate
        self.Q = Q  # Pheromone deposit factor

    def run(self, distance_matrix):
        """Run the ACO algorithm for a given distance matrix (task-VM execution times)."""
        num_tasks, num_vms = distance_matrix.shape

        # Compute heuristic values (η_ij = 1 / d_ij), avoiding division by zero
        heuristic_matrix = np.where(distance_matrix > 0, 1 / distance_matrix, 1e-10)

        # Initialize pheromone matrix (τ_ij = 1)
        pheromone_matrix = np.ones((num_tasks, num_vms))

        # Track best solution
        best_solution = None
        best_makespan = float('inf')
        best_vm_loads = None  # Store best VM loads

        # ACO Algorithm
        for iteration in range(self.num_iterations):
            all_solutions = []
            all_makespans = []
            all_vm_loads = []

            for ant in range(self.num_ants):
                solution = []
                vm_loads = np.zeros(num_vms)  # Initialize VM loads

                for task in range(num_tasks):
                    # Compute probabilities for each VM
                    probabilities = (pheromone_matrix[task] ** self.alpha) * (heuristic_matrix[task] ** self.beta)

                    # Add a small value to avoid zero division
                    prob_sum = probabilities.sum()
                    if prob_sum == 0:
                      probabilities = np.ones(num_vms) / num_vms  # Reset to equal probability
                    else:
                      probabilities /= prob_sum

                    # Select VM based on probability
                    vm_choice = np.random.choice(num_vms, p=probabilities)
                    solution.append((task, vm_choice))
                    vm_loads[vm_choice] += distance_matrix[task, vm_choice]  # Update VM load

                # Compute makespan
                makespan = max(vm_loads)
                all_solutions.append(solution)
                all_makespans.append(makespan)
                all_vm_loads.append(vm_loads.copy())

            # Select best solution from this iteration
            min_index = np.argmin(all_makespans)
            if all_makespans[min_index] < best_makespan:
                best_makespan = all_makespans[min_index]
                best_solution = all_solutions[min_index]
                best_vm_loads = all_vm_loads[min_index]

            # Pheromone update
            pheromone_matrix *= (1 - self.rho)  # Evaporation
            for task, vm in best_solution:
                pheromone_matrix[task, vm] += self.Q / best_makespan

        return best_solution, best_makespan, best_vm_loads, all_makespans

# %% [markdown]
# Apply ACO on a Small Example

# %%
# Apply ACO on a Small Example

# Define a small 5-task, 3-VM problem
small_distance_matrix = np.array([
    [7, 8, 5],
    [6, 7, 9],
    [8, 5, 6],
    [9, 6, 7],
    [5, 9, 8]
])

# Initialize and Run ACO
aco = AntColonyOptimization(num_ants=5, num_iterations=50, alpha=1, beta=2, rho=0.1, Q=100)
best_solution, best_makespan, _ , _ = aco.run(small_distance_matrix)

# Print results for the small example
print("\n Small Example:")
print(f"Best Solution: {best_solution}")
print(f"Best Makespan: {best_makespan}")
# Out:
#  Small Example:
# Best Solution: [(0, 2), (1, 0), (2, 1), (3, 1), (4, 0)]
# Best Makespan: 11.0

# %% [markdown]
# Test ACO On Generated Dataset

# %%
# Initialize ACO
aco = AntColonyOptimization(num_ants=10, num_iterations=100, alpha=0.3, beta=1, rho=0.5, Q=100)

# Store Results for Plotting
results = {
    "dataset": [],
    "num_tasks": [],
    "best_makespan": [],
    "worst_makespan": [],
    "avg_makespan": [],
    "degree_of_imbalance": []
}

# Dataset path (change this to your directory)
dataset_path = "dataset"
dataset_files = os.listdir(dataset_path)

# Apply ACO to All Datasets and Collect Data
for dataset_file in dataset_files:
    file_path = os.path.join(dataset_path, dataset_file)
    tasks, vms, times = read_data(file_path)

    # Extract task and VM counts
    num_tasks = len(tasks)
    num_vms = len(vms)


    # Create distance matrix
    distance_matrix = np.zeros((num_tasks, num_vms))
    for (task, vm), time in times.items():
        distance_matrix[task - 1, vm - 1] = time  # Adjust index for 0-based array
    # print(f"\nDistance Matrix for {dataset_file}:\n", distance_matrix)

    # Run ACO
    aco.num_tasks = num_tasks
    aco.num_vms = num_vms
    aco.distance_matrix = distance_matrix

    best_solution, best_makespan, best_vm_loads, all_makespans = aco.run(distance_matrix)

    # Compute Best, Worst, and Average Makespan
    worst_makespan = max(all_makespans)  # Worst makespan (highest)
    avg_makespan = np.mean(all_makespans)  # # Average best makespan per iteration

    # Compute Load Imbalance: Balance Factor = Max Load / Average Load
    avg_load = np.mean(best_vm_loads)
    max_load = np.max(best_vm_loads)

    # Compute Corrected Degree of Imbalance (DI)
    degree_of_imbalance = compute_degree_of_imbalance(best_vm_loads)
    print("\nBest VM Loads for", dataset_file, ":", best_vm_loads)
    print(f"Computed Best Makespan (max VM load): {max(best_vm_loads)}")
    print(f"Total Task Execution Time for {dataset_file}: {np.sum(distance_matrix)}")

    # Store Results
    results["dataset"].append(dataset_file)
    results["num_tasks"].append(num_tasks)
    results["best_makespan"].append(best_makespan)
    results["worst_makespan"].append(worst_makespan)
    results["avg_makespan"].append(avg_makespan)
    results["degree_of_imbalance"].append(degree_of_imbalance)

# Convert results to DataFrame
df_results = pd.DataFrame(results)
print(df_results)
# Out:
# Streaming output truncated to the last 5000 lines.
# Total Task Execution Time for instance_7_100_10_20.txt: 7406.0
#
# Best VM Loads for instance_7_50_10_8.txt : [37. 34. 30. 32. 34. 38. 26. 35. 38. 32.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_7_50_10_8.txt: 3757.0
#
# Best VM Loads for instance_10_70_10_12.txt : [51. 49. 49. 52. 32. 49. 52. 49. 43. 52.]
# Computed Best Makespan (max VM load): 52.0
# Total Task Execution Time for instance_10_70_10_12.txt: 5277.0
#
# Best VM Loads for instance_2_90_10_4.txt : [65. 65. 62. 67. 63. 62. 65. 63. 60. 67.]
# Computed Best Makespan (max VM load): 67.0
# Total Task Execution Time for instance_2_90_10_4.txt: 6802.0
#
# Best VM Loads for instance_2_90_10_19.txt : [70. 70. 68. 60. 50. 62. 57. 51. 65. 70.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_2_90_10_19.txt: 6714.0
#
# Best VM Loads for instance_3_80_10_7.txt : [61. 53. 42. 55. 59. 61. 50. 53. 54. 59.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_3_80_10_7.txt: 6066.0
#
# Best VM Loads for instance_1_70_10_17.txt : [49. 43. 39. 39. 44. 44. 46. 50. 50. 49.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_1_70_10_17.txt: 5355.0
#
# Best VM Loads for instance_2_40_10_17.txt : [29. 29. 29. 21. 34. 21. 25. 34. 34. 31.]
# Computed Best Makespan (max VM load): 34.0
# Total Task Execution Time for instance_2_40_10_17.txt: 3027.0
#
# Best VM Loads for instance_6_50_10_17.txt : [39. 29. 39. 29. 38. 32. 31. 34. 39. 20.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_6_50_10_17.txt: 3789.0
#
# Best VM Loads for instance_2_80_10_4.txt : [55. 58. 54. 50. 30. 56. 52. 58. 55. 56.]
# Computed Best Makespan (max VM load): 58.0
# Total Task Execution Time for instance_2_80_10_4.txt: 5939.0
#
# Best VM Loads for instance_2_90_10_7.txt : [53. 58. 59. 61. 59. 53. 51. 56. 45. 61.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_2_90_10_7.txt: 6620.0
#
# Best VM Loads for instance_8_40_10_20.txt : [29. 18. 26. 19. 33. 32. 29. 33. 31. 30.]
# Computed Best Makespan (max VM load): 33.0
# Total Task Execution Time for instance_8_40_10_20.txt: 3027.0
#
# Best VM Loads for instance_6_70_10_7.txt : [49. 36. 41. 51. 53. 46. 43. 53. 50. 53.]
# Computed Best Makespan (max VM load): 53.0
# Total Task Execution Time for instance_6_70_10_7.txt: 5278.0
#
# Best VM Loads for instance_10_60_10_12.txt : [50. 36. 41. 47. 31. 45. 38. 40. 50. 45.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_10_60_10_12.txt: 4506.0
#
# Best VM Loads for instance_3_100_10_16.txt : [67. 59. 69. 63. 67. 65. 67. 62. 67. 63.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_3_100_10_16.txt: 7456.0
#
# Best VM Loads for instance_6_60_10_19.txt : [43. 33. 43. 43. 25. 42. 41. 34. 38. 39.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_6_60_10_19.txt: 4535.0
#
# Best VM Loads for instance_6_70_10_5.txt : [44. 26. 48. 42. 47. 44. 48. 47. 49. 48.]
# Computed Best Makespan (max VM load): 49.0
# Total Task Execution Time for instance_6_70_10_5.txt: 5197.0
#
# Best VM Loads for instance_3_10_10_17.txt : [11.  5.  0.  7.  0. 11.  0. 10.  8. 10.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_3_10_10_17.txt: 748.0
#
# Best VM Loads for instance_1_60_10_18.txt : [25. 47. 37. 46. 35. 45. 43. 43. 47. 44.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_1_60_10_18.txt: 4541.0
#
# Best VM Loads for instance_3_70_10_18.txt : [41. 47. 35. 45. 55. 55. 53. 38. 54. 55.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_3_70_10_18.txt: 5236.0
#
# Best VM Loads for instance_2_100_10_5.txt : [62. 68. 62. 66. 67. 68. 67. 65. 53. 66.]
# Computed Best Makespan (max VM load): 68.0
# Total Task Execution Time for instance_2_100_10_5.txt: 7500.0
#
# Best VM Loads for instance_9_50_10_9.txt : [31. 27. 27. 30. 36. 32. 35. 37. 26. 34.]
# Computed Best Makespan (max VM load): 37.0
# Total Task Execution Time for instance_9_50_10_9.txt: 3727.0
#
# Best VM Loads for instance_9_90_10_5.txt : [60. 44. 58. 65. 63. 64. 59. 62. 64. 68.]
# Computed Best Makespan (max VM load): 68.0
# Total Task Execution Time for instance_9_90_10_5.txt: 6792.0
#
# Best VM Loads for instance_1_90_10_17.txt : [61. 43. 60. 63. 57. 61. 58. 62. 60. 59.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_1_90_10_17.txt: 6756.0
#
# Best VM Loads for instance_4_10_10_2.txt : [10.  7.  5. 10.  5.  7.  6.  9.  6.  6.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_4_10_10_2.txt: 754.0
#
# Best VM Loads for instance_10_50_10_12.txt : [32. 32. 34. 38. 36. 36. 36. 31. 26. 38.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_10_50_10_12.txt: 3796.0
#
# Best VM Loads for instance_3_20_10_15.txt : [17. 13. 11. 13. 10. 11. 12. 15. 14. 15.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_3_20_10_15.txt: 1461.0
#
# Best VM Loads for instance_5_100_10_17.txt : [65. 69. 72. 63. 75. 75. 59. 77. 73. 65.]
# Computed Best Makespan (max VM load): 77.0
# Total Task Execution Time for instance_5_100_10_17.txt: 7480.0
#
# Best VM Loads for instance_8_10_10_10.txt : [ 8.  9.  8.  6. 10.  8. 10.  5. 10.  8.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_8_10_10_10.txt: 754.0
#
# Best VM Loads for instance_9_10_10_17.txt : [7. 5. 5. 6. 8. 5. 7. 6. 5. 5.]
# Computed Best Makespan (max VM load): 8.0
# Total Task Execution Time for instance_9_10_10_17.txt: 761.0
#
# Best VM Loads for instance_3_50_10_12.txt : [34. 39. 40. 20. 25. 27. 40. 40. 44. 43.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_3_50_10_12.txt: 3836.0
#
# Best VM Loads for instance_7_100_10_8.txt : [65. 67. 64. 71. 68. 69. 73. 69. 57. 65.]
# Computed Best Makespan (max VM load): 73.0
# Total Task Execution Time for instance_7_100_10_8.txt: 7526.0
#
# Best VM Loads for instance_4_30_10_6.txt : [16. 21. 23. 16. 23. 17. 23. 20. 21. 19.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_4_30_10_6.txt: 2282.0
#
# Best VM Loads for instance_3_80_10_8.txt : [54. 53. 57. 48. 56. 43. 54. 55. 57. 53.]
# Computed Best Makespan (max VM load): 57.0
# Total Task Execution Time for instance_3_80_10_8.txt: 5987.0
#
# Best VM Loads for instance_3_40_10_8.txt : [34. 33. 28. 22. 33. 21. 27. 29. 34. 21.]
# Computed Best Makespan (max VM load): 34.0
# Total Task Execution Time for instance_3_40_10_8.txt: 3001.0
#
# Best VM Loads for instance_9_10_10_7.txt : [8. 5. 5. 7. 9. 8. 6. 9. 7. 8.]
# Computed Best Makespan (max VM load): 9.0
# Total Task Execution Time for instance_9_10_10_7.txt: 765.0
#
# Best VM Loads for instance_8_40_10_6.txt : [29. 29. 24. 28. 25. 18. 22. 31. 23. 27.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_8_40_10_6.txt: 2957.0
#
# Best VM Loads for instance_10_40_10_7.txt : [29. 29. 29. 22. 24. 28. 27. 18. 16. 29.]
# Computed Best Makespan (max VM load): 29.0
# Total Task Execution Time for instance_10_40_10_7.txt: 2999.0
#
# Best VM Loads for instance_2_40_10_4.txt : [19. 30. 23. 32. 27. 12. 32. 30. 29. 32.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_2_40_10_4.txt: 3048.0
#
# Best VM Loads for instance_6_100_10_1.txt : [66. 60. 74. 46. 75. 72. 74. 73. 75. 73.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_6_100_10_1.txt: 7526.0
#
# Best VM Loads for instance_2_60_10_14.txt : [46. 41. 37. 45. 44. 30. 31. 48. 48. 43.]
# Computed Best Makespan (max VM load): 48.0
# Total Task Execution Time for instance_2_60_10_14.txt: 4571.0
#
# Best VM Loads for instance_7_100_10_14.txt : [56. 76. 70. 72. 73. 72. 70. 56. 54. 77.]
# Computed Best Makespan (max VM load): 77.0
# Total Task Execution Time for instance_7_100_10_14.txt: 7508.0
#
# Best VM Loads for instance_8_100_10_8.txt : [62. 69. 68. 64. 64. 66. 67. 67. 62. 58.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_8_100_10_8.txt: 7504.0
#
# Best VM Loads for instance_6_80_10_20.txt : [49. 57. 59. 52. 56. 51. 59. 56. 58. 53.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_6_80_10_20.txt: 6024.0
#
# Best VM Loads for instance_6_70_10_20.txt : [47. 48. 46. 43. 51. 45. 46. 49. 33. 48.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_6_70_10_20.txt: 5239.0
#
# Best VM Loads for instance_2_10_10_11.txt : [13.  5.  0.  7.  7. 13.  9. 10.  5.  0.]
# Computed Best Makespan (max VM load): 13.0
# Total Task Execution Time for instance_2_10_10_11.txt: 736.0
#
# Best VM Loads for instance_2_80_10_20.txt : [64. 61. 60. 39. 52. 64. 33. 59. 51. 57.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_2_80_10_20.txt: 5925.0
#
# Best VM Loads for instance_10_80_10_17.txt : [47. 57. 58. 55. 49. 55. 58. 57. 55. 55.]
# Computed Best Makespan (max VM load): 58.0
# Total Task Execution Time for instance_10_80_10_17.txt: 6114.0
#
# Best VM Loads for instance_8_90_10_12.txt : [69. 54. 61. 57. 50. 67. 55. 69. 50. 67.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_8_90_10_12.txt: 6794.0
#
# Best VM Loads for instance_7_50_10_1.txt : [35. 36. 34. 26. 24. 38. 37. 34. 25. 38.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_7_50_10_1.txt: 3736.0
#
# Best VM Loads for instance_8_90_10_9.txt : [54. 63. 58. 61. 63. 60. 57. 62. 58. 58.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_8_90_10_9.txt: 6719.0
#
# Best VM Loads for instance_4_90_10_2.txt : [49. 69. 65. 61. 55. 69. 64. 70. 70. 43.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_4_90_10_2.txt: 6773.0
#
# Best VM Loads for instance_6_70_10_12.txt : [45. 35. 50. 41. 47. 50. 42. 46. 49. 44.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_6_70_10_12.txt: 5279.0
#
# Best VM Loads for instance_9_100_10_13.txt : [67. 65. 66. 69. 66. 64. 64. 68. 69. 68.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_9_100_10_13.txt: 7509.0
#
# Best VM Loads for instance_1_70_10_4.txt : [53. 56. 52. 41. 55. 56. 56. 51. 50. 34.]
# Computed Best Makespan (max VM load): 56.0
# Total Task Execution Time for instance_1_70_10_4.txt: 5237.0
#
# Best VM Loads for instance_7_20_10_20.txt : [20. 20.  5.  0. 12. 11. 19. 15. 11. 15.]
# Computed Best Makespan (max VM load): 20.0
# Total Task Execution Time for instance_7_20_10_20.txt: 1501.0
#
# Best VM Loads for instance_6_70_10_4.txt : [39. 39. 47. 49. 48. 44. 49. 47. 49. 36.]
# Computed Best Makespan (max VM load): 49.0
# Total Task Execution Time for instance_6_70_10_4.txt: 5276.0
#
# Best VM Loads for instance_10_10_10_2.txt : [ 8.  8.  5. 10.  7.  0.  0. 10.  5.  6.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_10_10_10_2.txt: 752.0
#
# Best VM Loads for instance_4_10_10_9.txt : [10.  5.  6. 10.  9.  8.  0.  7.  5.  6.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_4_10_10_9.txt: 736.0
#
# Best VM Loads for instance_1_30_10_9.txt : [21. 15. 21. 19. 21. 26. 26. 25. 22. 20.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_1_30_10_9.txt: 2258.0
#
# Best VM Loads for instance_2_80_10_5.txt : [56. 57. 62. 46. 58. 58. 42. 60. 62. 42.]
# Computed Best Makespan (max VM load): 62.0
# Total Task Execution Time for instance_2_80_10_5.txt: 5948.0
#
# Best VM Loads for instance_1_30_10_7.txt : [27. 19. 22. 27. 22. 24. 13. 16.  5. 23.]
# Computed Best Makespan (max VM load): 27.0
# Total Task Execution Time for instance_1_30_10_7.txt: 2243.0
#
# Best VM Loads for instance_6_80_10_1.txt : [52. 57. 48. 51. 57. 51. 56. 55. 55. 49.]
# Computed Best Makespan (max VM load): 57.0
# Total Task Execution Time for instance_6_80_10_1.txt: 5963.0
#
# Best VM Loads for instance_7_60_10_18.txt : [41. 40. 43. 46. 40. 37. 39. 44. 44. 39.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_7_60_10_18.txt: 4517.0
#
# Best VM Loads for instance_5_70_10_15.txt : [21. 44. 58. 35. 57. 57. 51. 52. 51. 58.]
# Computed Best Makespan (max VM load): 58.0
# Total Task Execution Time for instance_5_70_10_15.txt: 5229.0
#
# Best VM Loads for instance_7_70_10_12.txt : [46. 46. 44. 51. 50. 50. 44. 50. 44. 41.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_7_70_10_12.txt: 5252.0
#
# Best VM Loads for instance_8_20_10_5.txt : [ 5.  0. 19. 16. 16. 11. 18. 19. 19.  7.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_8_20_10_5.txt: 1498.0
#
# Best VM Loads for instance_5_80_10_12.txt : [27. 47. 55. 61. 47. 61. 60. 57. 59. 52.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_5_80_10_12.txt: 5951.0
#
# Best VM Loads for instance_3_100_10_3.txt : [62. 69. 68. 67. 66. 63. 65. 70. 62. 67.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_3_100_10_3.txt: 7461.0
#
# Best VM Loads for instance_9_50_10_16.txt : [33. 34. 31. 37. 30. 35. 38. 28. 37. 37.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_9_50_10_16.txt: 3739.0
#
# Best VM Loads for instance_3_10_10_1.txt : [6. 5. 9. 8. 5. 8. 7. 6. 6. 5.]
# Computed Best Makespan (max VM load): 9.0
# Total Task Execution Time for instance_3_10_10_1.txt: 740.0
#
# Best VM Loads for instance_10_80_10_10.txt : [54. 53. 56. 59. 59. 35. 57. 52. 44. 51.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_10_80_10_10.txt: 6038.0
#
# Best VM Loads for instance_10_100_10_13.txt : [70. 50. 67. 71. 67. 65. 72. 63. 71. 59.]
# Computed Best Makespan (max VM load): 72.0
# Total Task Execution Time for instance_10_100_10_13.txt: 7437.0
#
# Best VM Loads for instance_3_20_10_12.txt : [15. 13. 12.  8. 16.  9. 15. 19. 15. 14.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_3_20_10_12.txt: 1529.0
#
# Best VM Loads for instance_10_40_10_3.txt : [28. 28. 31. 19. 22. 26. 24. 28. 22. 27.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_10_40_10_3.txt: 2957.0
#
# Best VM Loads for instance_1_50_10_15.txt : [29. 33. 38. 31. 38. 35. 36. 32. 33. 38.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_1_50_10_15.txt: 3727.0
#
# Best VM Loads for instance_1_20_10_18.txt : [15. 12. 19. 10.  5. 19. 19. 12. 12.  0.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_1_20_10_18.txt: 1502.0
#
# Best VM Loads for instance_6_80_10_5.txt : [51. 63. 47. 30. 61. 63. 63. 45. 61. 55.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_6_80_10_5.txt: 6047.0
#
# Best VM Loads for instance_2_20_10_3.txt : [22.  7.  0. 21. 19. 13.  9.  5. 21. 22.]
# Computed Best Makespan (max VM load): 22.0
# Total Task Execution Time for instance_2_20_10_3.txt: 1525.0
#
# Best VM Loads for instance_6_40_10_7.txt : [32. 32. 20. 29. 28. 21. 28. 27. 28. 32.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_6_40_10_7.txt: 2964.0
#
# Best VM Loads for instance_9_50_10_5.txt : [37. 22. 34. 31. 35. 39. 33. 34. 37. 33.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_9_50_10_5.txt: 3780.0
#
# Best VM Loads for instance_9_20_10_10.txt : [10. 13. 16. 10. 13.  8. 16. 15. 13. 13.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_9_20_10_10.txt: 1546.0
#
# Best VM Loads for instance_7_90_10_17.txt : [56. 66. 61. 63. 66. 64. 52. 53. 52. 64.]
# Computed Best Makespan (max VM load): 66.0
# Total Task Execution Time for instance_7_90_10_17.txt: 6735.0
#
# Best VM Loads for instance_1_80_10_12.txt : [59. 58. 48. 48. 57. 61. 61. 61. 43. 53.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_1_80_10_12.txt: 6010.0
#
# Best VM Loads for instance_7_50_10_12.txt : [29. 38. 40. 25. 38. 39. 20. 38. 38. 35.]
# Computed Best Makespan (max VM load): 40.0
# Total Task Execution Time for instance_7_50_10_12.txt: 3801.0
#
# Best VM Loads for instance_10_70_10_5.txt : [49. 51. 51. 40. 46. 43. 45. 48. 45. 43.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_10_70_10_5.txt: 5249.0
#
# Best VM Loads for instance_8_100_10_9.txt : [66. 69. 72. 72. 69. 69. 73. 75. 71. 56.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_8_100_10_9.txt: 7458.0
#
# Best VM Loads for instance_6_60_10_12.txt : [41. 43. 44. 35. 41. 44. 39. 44. 26. 44.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_6_60_10_12.txt: 4518.0
#
# Best VM Loads for instance_8_60_10_7.txt : [46. 43. 38. 42. 46. 32. 41. 37. 32. 32.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_8_60_10_7.txt: 4505.0
#
# Best VM Loads for instance_3_10_10_13.txt : [10.  0.  6.  6. 10.  6.  7.  7.  8.  6.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_3_10_10_13.txt: 744.0
#
# Best VM Loads for instance_8_90_10_2.txt : [69. 56. 55. 67. 39. 54. 63. 65. 65. 56.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_8_90_10_2.txt: 6761.0
#
# Best VM Loads for instance_10_20_10_9.txt : [ 6. 11. 18. 12. 17.  6. 10. 12. 18. 14.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_10_20_10_9.txt: 1533.0
#
# Best VM Loads for instance_1_30_10_13.txt : [23. 22. 12. 16. 23. 24. 25. 22. 25. 18.]
# Computed Best Makespan (max VM load): 25.0
# Total Task Execution Time for instance_1_30_10_13.txt: 2207.0
#
# Best VM Loads for instance_3_60_10_6.txt : [38. 38. 28. 38. 43. 48. 41. 48. 45. 45.]
# Computed Best Makespan (max VM load): 48.0
# Total Task Execution Time for instance_3_60_10_6.txt: 4496.0
#
# Best VM Loads for instance_4_30_10_5.txt : [25. 22. 11. 23. 26. 11. 26. 22. 18. 26.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_4_30_10_5.txt: 2262.0
#
# Best VM Loads for instance_1_20_10_19.txt : [19. 17. 19. 12.  7.  9.  8. 18. 19.  5.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_1_20_10_19.txt: 1475.0
#
# Best VM Loads for instance_2_80_10_10.txt : [59. 56. 63. 52. 43. 56. 63. 63. 58. 56.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_2_80_10_10.txt: 6051.0
#
# Best VM Loads for instance_7_70_10_20.txt : [45. 43. 46. 47. 49. 48. 42. 48. 49. 45.]
# Computed Best Makespan (max VM load): 49.0
# Total Task Execution Time for instance_7_70_10_20.txt: 5275.0
#
# Best VM Loads for instance_5_90_10_11.txt : [57. 67. 62. 61. 59. 64. 67. 58. 60. 67.]
# Computed Best Makespan (max VM load): 67.0
# Total Task Execution Time for instance_5_90_10_11.txt: 6727.0
#
# Best VM Loads for instance_6_10_10_11.txt : [ 7.  6. 10.  6. 10.  6.  6.  0.  9. 10.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_6_10_10_11.txt: 760.0
#
# Best VM Loads for instance_10_100_10_12.txt : [70. 75. 64. 70. 70. 69. 74. 62. 75. 63.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_10_100_10_12.txt: 7556.0
#
# Best VM Loads for instance_2_70_10_9.txt : [48. 44. 51. 48. 49. 46. 47. 50. 47. 46.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_2_70_10_9.txt: 5292.0
#
# Best VM Loads for instance_6_70_10_18.txt : [47. 48. 52. 53. 36. 51. 47. 51. 53. 47.]
# Computed Best Makespan (max VM load): 53.0
# Total Task Execution Time for instance_6_70_10_18.txt: 5280.0
#
# Best VM Loads for instance_8_80_10_4.txt : [46. 44. 50. 51. 43. 57. 49. 61. 53. 61.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_8_80_10_4.txt: 6030.0
#
# Best VM Loads for instance_9_40_10_1.txt : [27. 31. 31. 28. 18. 21. 29. 30. 27. 14.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_9_40_10_1.txt: 2946.0
#
# Best VM Loads for instance_7_80_10_15.txt : [54. 59. 48. 56. 59. 53. 59. 52. 59. 51.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_7_80_10_15.txt: 6041.0
#
# Best VM Loads for instance_3_70_10_2.txt : [35. 51. 49. 50. 50. 50. 45. 44. 47. 47.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_3_70_10_2.txt: 5162.0
#
# Best VM Loads for instance_7_30_10_1.txt : [26. 15. 19. 15. 22. 23. 21. 12. 19. 26.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_7_30_10_1.txt: 2270.0
#
# Best VM Loads for instance_2_70_10_13.txt : [51. 54. 50. 42. 40. 46. 41. 53. 55. 55.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_2_70_10_13.txt: 5272.0
#
# Best VM Loads for instance_8_20_10_7.txt : [11. 18.  6. 13. 12. 15.  5. 18. 14. 16.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_8_20_10_7.txt: 1498.0
#
# Best VM Loads for instance_9_70_10_10.txt : [48. 50. 48. 47. 48. 36. 50. 49. 54. 54.]
# Computed Best Makespan (max VM load): 54.0
# Total Task Execution Time for instance_9_70_10_10.txt: 5290.0
#
# Best VM Loads for instance_9_20_10_11.txt : [15. 13. 15. 14. 17.  6. 14. 15. 13. 17.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_9_20_10_11.txt: 1528.0
#
# Best VM Loads for instance_1_60_10_14.txt : [29. 39. 44. 41. 44. 37. 43. 38. 41. 41.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_1_60_10_14.txt: 4502.0
#
# Best VM Loads for instance_5_70_10_9.txt : [46. 51. 48. 36. 49. 49. 51. 50. 49. 32.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_5_70_10_9.txt: 5184.0
#
# Best VM Loads for instance_1_80_10_16.txt : [55. 53. 49. 53. 59. 45. 52. 59. 58. 59.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_1_80_10_16.txt: 6029.0
#
# Best VM Loads for instance_4_20_10_16.txt : [15. 12. 15. 13. 12. 15. 16. 11.  8.  6.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_4_20_10_16.txt: 1473.0
#
# Best VM Loads for instance_4_30_10_9.txt : [15. 20. 20. 23. 12. 18. 23. 21. 21. 19.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_4_30_10_9.txt: 2260.0
#
# Best VM Loads for instance_6_20_10_20.txt : [16.  6.  8. 14. 10. 16. 16. 12. 16. 10.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_6_20_10_20.txt: 1500.0
#
# Best VM Loads for instance_1_10_10_15.txt : [6. 6. 9. 5. 7. 9. 7. 7. 8. 6.]
# Computed Best Makespan (max VM load): 9.0
# Total Task Execution Time for instance_1_10_10_15.txt: 761.0
#
# Best VM Loads for instance_6_30_10_10.txt : [12. 23. 19. 12. 21. 19. 22. 16. 23. 20.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_6_30_10_10.txt: 2241.0
#
# Best VM Loads for instance_9_10_10_5.txt : [ 0. 10. 12. 11.  0.  0.  7.  6. 12.  7.]
# Computed Best Makespan (max VM load): 12.0
# Total Task Execution Time for instance_9_10_10_5.txt: 738.0
#
# Best VM Loads for instance_6_50_10_4.txt : [35. 36. 30. 34. 36. 33. 19. 36. 28. 34.]
# Computed Best Makespan (max VM load): 36.0
# Total Task Execution Time for instance_6_50_10_4.txt: 3762.0
#
# Best VM Loads for instance_1_80_10_20.txt : [52. 49. 50. 52. 55. 55. 47. 51. 52. 49.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_1_80_10_20.txt: 6031.0
#
# Best VM Loads for instance_10_30_10_9.txt : [17. 21. 21. 21. 19. 19. 16. 16. 21. 22.]
# Computed Best Makespan (max VM load): 22.0
# Total Task Execution Time for instance_10_30_10_9.txt: 2253.0
#
# Best VM Loads for instance_6_40_10_4.txt : [32. 30. 24. 30. 24. 16. 19. 26. 32. 20.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_6_40_10_4.txt: 2925.0
#
# Best VM Loads for instance_10_10_10_17.txt : [10.  0.  7. 10. 10.  9. 10.  0.  5.  5.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_10_10_10_17.txt: 763.0
#
# Best VM Loads for instance_3_70_10_6.txt : [48. 52. 47. 45. 33. 55. 55. 47. 50. 40.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_3_70_10_6.txt: 5340.0
#
# Best VM Loads for instance_4_10_10_12.txt : [ 6.  7.  6.  8.  9.  0. 10.  6.  5.  7.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_4_10_10_12.txt: 752.0
#
# Best VM Loads for instance_6_40_10_19.txt : [33. 28. 29. 29. 21. 31. 28. 33. 24. 11.]
# Computed Best Makespan (max VM load): 33.0
# Total Task Execution Time for instance_6_40_10_19.txt: 3044.0
#
# Best VM Loads for instance_6_100_10_7.txt : [56. 74. 63. 71. 68. 55. 77. 77. 69. 75.]
# Computed Best Makespan (max VM load): 77.0
# Total Task Execution Time for instance_6_100_10_7.txt: 7609.0
#
# Best VM Loads for instance_7_10_10_7.txt : [ 8.  7.  6.  5.  5. 10.  0.  7. 10.  5.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_7_10_10_7.txt: 736.0
#
# Best VM Loads for instance_5_60_10_7.txt : [46. 44. 46. 41. 38. 39. 42. 38. 46. 46.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_5_60_10_7.txt: 4519.0
#
# Best VM Loads for instance_4_90_10_6.txt : [53. 57. 62. 62. 65. 65. 52. 64. 60. 59.]
# Computed Best Makespan (max VM load): 65.0
# Total Task Execution Time for instance_4_90_10_6.txt: 6757.0
#
# Best VM Loads for instance_9_50_10_20.txt : [36. 28. 34. 38. 35. 34. 37. 36. 24. 38.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_9_50_10_20.txt: 3718.0
#
# Best VM Loads for instance_10_50_10_17.txt : [30. 35. 25. 36. 29. 36. 29. 36. 36. 33.]
# Computed Best Makespan (max VM load): 36.0
# Total Task Execution Time for instance_10_50_10_17.txt: 3764.0
#
# Best VM Loads for instance_7_40_10_17.txt : [32. 28. 29. 27. 29. 20. 29. 31. 28. 29.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_7_40_10_17.txt: 3046.0
#
# Best VM Loads for instance_10_60_10_6.txt : [46. 36. 36. 37. 31. 45. 43. 46. 45. 41.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_10_60_10_6.txt: 4453.0
#
# Best VM Loads for instance_10_70_10_16.txt : [48. 51. 46. 42. 51. 47. 50. 47. 45. 49.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_10_70_10_16.txt: 5252.0
#
# Best VM Loads for instance_8_10_10_15.txt : [ 9.  9.  6.  7.  9.  7.  0.  7.  8. 10.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_8_10_10_15.txt: 720.0
#
# Best VM Loads for instance_6_50_10_1.txt : [43. 34. 43. 21. 38. 40. 37. 42. 36. 21.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_6_50_10_1.txt: 3737.0
#
# Best VM Loads for instance_8_80_10_6.txt : [55. 60. 37. 62. 59. 63. 63. 59. 55. 57.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_8_80_10_6.txt: 6060.0
#
# Best VM Loads for instance_6_80_10_4.txt : [57. 61. 54. 58. 55. 60. 55. 51. 46. 61.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_6_80_10_4.txt: 5973.0
#
# Best VM Loads for instance_6_100_10_14.txt : [67. 63. 70. 71. 71. 73. 74. 59. 63. 61.]
# Computed Best Makespan (max VM load): 74.0
# Total Task Execution Time for instance_6_100_10_14.txt: 7492.0
#
# Best VM Loads for instance_3_90_10_17.txt : [63. 64. 60. 60. 61. 60. 62. 63. 57. 47.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_3_90_10_17.txt: 6822.0
#
# Best VM Loads for instance_4_50_10_18.txt : [39. 39. 38. 23. 35. 38. 31. 36. 25. 37.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_4_50_10_18.txt: 3754.0
#
# Best VM Loads for instance_9_60_10_9.txt : [39. 44. 40. 46. 44. 29. 43. 44. 42. 47.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_9_60_10_9.txt: 4512.0
#
# Best VM Loads for instance_9_20_10_16.txt : [13. 17. 11. 12. 14. 16.  9. 10. 14. 16.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_9_20_10_16.txt: 1476.0
#
# Best VM Loads for instance_1_40_10_8.txt : [31. 25. 26. 27. 31. 14. 27. 29. 31. 21.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_1_40_10_8.txt: 3042.0
#
# Best VM Loads for instance_6_90_10_9.txt : [64. 59. 64. 65. 63. 59. 60. 59. 60. 57.]
# Computed Best Makespan (max VM load): 65.0
# Total Task Execution Time for instance_6_90_10_9.txt: 6626.0
#
# Best VM Loads for instance_10_50_10_9.txt : [28. 41. 34. 31. 41. 38. 41.  7. 34. 34.]
# Computed Best Makespan (max VM load): 41.0
# Total Task Execution Time for instance_10_50_10_9.txt: 3771.0
#
# Best VM Loads for instance_5_50_10_11.txt : [32. 41. 28. 29. 41. 36. 35. 30. 29. 41.]
# Computed Best Makespan (max VM load): 41.0
# Total Task Execution Time for instance_5_50_10_11.txt: 3815.0
#
# Best VM Loads for instance_10_90_10_9.txt : [65. 66. 51. 66. 66. 54. 57. 66. 54. 58.]
# Computed Best Makespan (max VM load): 66.0
# Total Task Execution Time for instance_10_90_10_9.txt: 6745.0
#
# Best VM Loads for instance_5_10_10_2.txt : [ 9.  7. 10.  5.  7.  5.  9.  7. 10.  0.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_5_10_10_2.txt: 777.0
#
# Best VM Loads for instance_5_80_10_6.txt : [58. 41. 56. 61. 41. 62. 62. 57. 54. 53.]
# Computed Best Makespan (max VM load): 62.0
# Total Task Execution Time for instance_5_80_10_6.txt: 6047.0
#
# Best VM Loads for instance_10_60_10_10.txt : [36. 47. 47. 45. 40. 33. 46. 35. 33. 42.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_10_60_10_10.txt: 4515.0
#
# Best VM Loads for instance_7_10_10_3.txt : [11.  7.  0.  7.  9.  8.  0.  7. 11.  6.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_7_10_10_3.txt: 785.0
#
# Best VM Loads for instance_1_90_10_16.txt : [65. 52. 59. 61. 56. 63. 65. 60. 59. 64.]
# Computed Best Makespan (max VM load): 65.0
# Total Task Execution Time for instance_1_90_10_16.txt: 6782.0
#
# Best VM Loads for instance_5_100_10_11.txt : [72. 74. 71. 51. 69. 66. 72. 71. 65. 70.]
# Computed Best Makespan (max VM load): 74.0
# Total Task Execution Time for instance_5_100_10_11.txt: 7500.0
#
# Best VM Loads for instance_4_100_10_19.txt : [64. 71. 69. 66. 69. 71. 71. 67. 65. 66.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_4_100_10_19.txt: 7489.0
#
# Best VM Loads for instance_4_10_10_7.txt : [10.  0.  6.  6.  5. 10.  9.  8.  8. 10.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_4_10_10_7.txt: 759.0
#
# Best VM Loads for instance_4_90_10_3.txt : [51. 60. 55. 61. 62. 63. 57. 60. 50. 58.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_4_90_10_3.txt: 6684.0
#
# Best VM Loads for instance_6_90_10_8.txt : [70. 62. 66. 60. 48. 66. 60. 60. 70. 51.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_6_90_10_8.txt: 6797.0
#
# Best VM Loads for instance_5_100_10_3.txt : [70. 73. 68. 45. 73. 66. 65. 67. 58. 71.]
# Computed Best Makespan (max VM load): 73.0
# Total Task Execution Time for instance_5_100_10_3.txt: 7498.0
#
# Best VM Loads for instance_7_90_10_14.txt : [52. 60. 56. 52. 64. 61. 58. 58. 61. 61.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_7_90_10_14.txt: 6810.0
#
# Best VM Loads for instance_4_20_10_13.txt : [19.  5. 14. 14. 15. 10.  5. 18. 14. 10.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_4_20_10_13.txt: 1461.0
#
# Best VM Loads for instance_6_10_10_15.txt : [ 5.  5.  9.  5.  5.  9.  7.  8. 10.  8.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_6_10_10_15.txt: 769.0
#
# Best VM Loads for instance_2_10_10_8.txt : [ 7.  6. 10.  5.  9. 10. 10.  0.  6.  0.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_2_10_10_8.txt: 748.0
#
# Best VM Loads for instance_10_70_10_18.txt : [53. 46. 46. 52. 33. 53. 52. 52. 45. 49.]
# Computed Best Makespan (max VM load): 53.0
# Total Task Execution Time for instance_10_70_10_18.txt: 5195.0
#
# Best VM Loads for instance_3_90_10_9.txt : [59. 67. 57. 69. 60. 71. 71. 48. 48. 71.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_3_90_10_9.txt: 6808.0
#
# Best VM Loads for instance_7_100_10_13.txt : [48. 69. 73. 75. 74. 59. 74. 74. 75. 58.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_7_100_10_13.txt: 7534.0
#
# Best VM Loads for instance_9_30_10_10.txt : [17. 15. 23. 22. 22. 19. 21. 21. 21. 12.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_9_30_10_10.txt: 2283.0
#
# Best VM Loads for instance_1_100_10_2.txt : [71. 58. 61. 66. 67. 71. 65. 63. 63. 68.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_1_100_10_2.txt: 7473.0
#
# Best VM Loads for instance_9_20_10_5.txt : [16. 10.  8. 15. 15. 15. 11. 12.  5. 16.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_9_20_10_5.txt: 1539.0
#
# Best VM Loads for instance_5_10_10_4.txt : [ 8.  6.  7.  8.  0. 10.  0.  6. 11. 11.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_5_10_10_4.txt: 739.0
#
# Best VM Loads for instance_1_40_10_19.txt : [29. 25. 20. 28. 29. 15. 25. 23. 29. 29.]
# Computed Best Makespan (max VM load): 29.0
# Total Task Execution Time for instance_1_40_10_19.txt: 3046.0
#
# Best VM Loads for instance_2_90_10_16.txt : [52. 66. 63. 65. 66. 66. 50. 52. 66. 53.]
# Computed Best Makespan (max VM load): 66.0
# Total Task Execution Time for instance_2_90_10_16.txt: 6628.0
#
# Best VM Loads for instance_7_30_10_5.txt : [17. 20. 20. 19. 14. 25. 15. 22. 26. 26.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_7_30_10_5.txt: 2229.0
#
# Best VM Loads for instance_2_40_10_2.txt : [28. 28. 28. 24. 28. 25. 32. 17. 12. 32.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_2_40_10_2.txt: 2995.0
#
# Best VM Loads for instance_6_100_10_6.txt : [68. 75. 62. 63. 71. 75. 75. 53. 68. 72.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_6_100_10_6.txt: 7553.0
#
# Best VM Loads for instance_10_50_10_7.txt : [18. 24. 38. 43. 43. 43. 43. 41. 37. 27.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_10_50_10_7.txt: 3841.0
#
# Best VM Loads for instance_2_50_10_6.txt : [40. 37. 33. 38. 39. 34. 20. 25. 40. 37.]
# Computed Best Makespan (max VM load): 40.0
# Total Task Execution Time for instance_2_50_10_6.txt: 3875.0
#
# Best VM Loads for instance_10_40_10_4.txt : [30. 35. 30. 15. 35. 32. 29. 24. 32. 22.]
# Computed Best Makespan (max VM load): 35.0
# Total Task Execution Time for instance_10_40_10_4.txt: 3010.0
#
# Best VM Loads for instance_4_100_10_14.txt : [72. 68. 72. 72. 68. 65. 68. 64. 58. 61.]
# Computed Best Makespan (max VM load): 72.0
# Total Task Execution Time for instance_4_100_10_14.txt: 7455.0
#
# Best VM Loads for instance_6_80_10_13.txt : [63. 51. 54. 57. 56. 50. 51. 51. 63. 63.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_6_80_10_13.txt: 6001.0
#
# Best VM Loads for instance_3_30_10_2.txt : [18. 16. 25. 25. 20. 21. 21. 17. 16.  0.]
# Computed Best Makespan (max VM load): 25.0
# Total Task Execution Time for instance_3_30_10_2.txt: 2271.0
#
# Best VM Loads for instance_10_90_10_1.txt : [50. 58. 56. 56. 52. 65. 64. 64. 65. 62.]
# Computed Best Makespan (max VM load): 65.0
# Total Task Execution Time for instance_10_90_10_1.txt: 6674.0
#
# Best VM Loads for instance_2_80_10_12.txt : [56. 56. 55. 55. 61. 56. 60. 59. 39. 43.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_2_80_10_12.txt: 6033.0
#
# Best VM Loads for instance_10_70_10_8.txt : [50. 48. 45. 41. 50. 49. 45. 40. 44. 47.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_10_70_10_8.txt: 5291.0
#
# Best VM Loads for instance_10_60_10_9.txt : [36. 32. 44. 40. 42. 33. 44. 43. 42. 42.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_10_60_10_9.txt: 4492.0
#
# Best VM Loads for instance_7_90_10_12.txt : [62. 63. 63. 56. 62. 60. 58. 61. 53. 50.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_7_90_10_12.txt: 6841.0
#
# Best VM Loads for instance_7_80_10_11.txt : [44. 54. 52. 60. 54. 59. 59. 59. 53. 55.]
# Computed Best Makespan (max VM load): 60.0
# Total Task Execution Time for instance_7_80_10_11.txt: 6019.0
#
# Best VM Loads for instance_7_40_10_1.txt : [35. 29. 35. 29. 25. 23.  8. 32. 22. 33.]
# Computed Best Makespan (max VM load): 35.0
# Total Task Execution Time for instance_7_40_10_1.txt: 3089.0
#
# Best VM Loads for instance_1_90_10_8.txt : [69. 61. 63. 48. 66. 66. 69. 69. 47. 65.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_1_90_10_8.txt: 6760.0
#
# Best VM Loads for instance_9_70_10_16.txt : [55. 20. 35. 55. 51. 47. 53. 51. 45. 47.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_9_70_10_16.txt: 5245.0
#
# Best VM Loads for instance_7_90_10_15.txt : [52. 67. 64. 56. 58. 52. 67. 67. 67. 60.]
# Computed Best Makespan (max VM load): 67.0
# Total Task Execution Time for instance_7_90_10_15.txt: 6676.0
#
# Best VM Loads for instance_5_60_10_12.txt : [40. 40. 41. 39. 42. 41. 40. 42. 35. 30.]
# Computed Best Makespan (max VM load): 42.0
# Total Task Execution Time for instance_5_60_10_12.txt: 4426.0
#
# Best VM Loads for instance_10_10_10_5.txt : [ 0.  0. 11.  5.  7.  8.  5.  6. 11.  9.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_10_10_10_5.txt: 755.0
#
# Best VM Loads for instance_1_60_10_4.txt : [44. 37. 28. 39. 44. 42. 46. 45. 40. 42.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_1_60_10_4.txt: 4510.0
#
# Best VM Loads for instance_9_70_10_20.txt : [47. 50. 44. 48. 45. 46. 46. 51. 45. 46.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_9_70_10_20.txt: 5243.0
#
# Best VM Loads for instance_3_30_10_17.txt : [27. 26. 24. 18. 20. 11. 22. 24. 22. 24.]
# Computed Best Makespan (max VM load): 27.0
# Total Task Execution Time for instance_3_30_10_17.txt: 2243.0
#
# Best VM Loads for instance_2_80_10_18.txt : [62. 17. 48. 47. 58. 60. 48. 62. 62. 57.]
# Computed Best Makespan (max VM load): 62.0
# Total Task Execution Time for instance_2_80_10_18.txt: 6007.0
#
# Best VM Loads for instance_2_60_10_6.txt : [32. 45. 46. 47. 43. 39. 30. 36. 44. 47.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_2_60_10_6.txt: 4487.0
#
# Best VM Loads for instance_6_70_10_16.txt : [44. 50. 44. 46. 50. 40. 50. 50. 47. 40.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_6_70_10_16.txt: 5195.0
#
# Best VM Loads for instance_10_50_10_14.txt : [33. 33. 32. 33. 30. 31. 34. 29. 29. 31.]
# Computed Best Makespan (max VM load): 34.0
# Total Task Execution Time for instance_10_50_10_14.txt: 3695.0
#
# Best VM Loads for instance_3_40_10_4.txt : [25. 29. 35. 35. 22. 29. 23. 30. 28. 19.]
# Computed Best Makespan (max VM load): 35.0
# Total Task Execution Time for instance_3_40_10_4.txt: 2966.0
#
# Best VM Loads for instance_6_30_10_7.txt : [20. 19. 25. 23. 23. 19. 14. 19. 25. 21.]
# Computed Best Makespan (max VM load): 25.0
# Total Task Execution Time for instance_6_30_10_7.txt: 2264.0
#
# Best VM Loads for instance_6_60_10_9.txt : [37. 40. 50. 29. 49. 43. 47. 29. 50. 30.]
# Computed Best Makespan (max VM load): 50.0
# Total Task Execution Time for instance_6_60_10_9.txt: 4549.0
#
# Best VM Loads for instance_7_100_10_9.txt : [73. 71. 72. 51. 68. 68. 71. 72. 75. 57.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_7_100_10_9.txt: 7518.0
#
# Best VM Loads for instance_4_90_10_20.txt : [61. 65. 41. 64. 67. 62. 64. 67. 64. 68.]
# Computed Best Makespan (max VM load): 68.0
# Total Task Execution Time for instance_4_90_10_20.txt: 6705.0
#
# Best VM Loads for instance_1_60_10_5.txt : [44. 43. 45. 31. 27. 35. 36. 43. 45. 41.]
# Computed Best Makespan (max VM load): 45.0
# Total Task Execution Time for instance_1_60_10_5.txt: 4474.0
#
# Best VM Loads for instance_3_60_10_11.txt : [36. 45. 36. 35. 44. 42. 45. 40. 45. 43.]
# Computed Best Makespan (max VM load): 45.0
# Total Task Execution Time for instance_3_60_10_11.txt: 4570.0
#
# Best VM Loads for instance_2_100_10_2.txt : [68. 64. 73. 70. 75. 66. 67. 53. 75. 68.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_2_100_10_2.txt: 7443.0
#
# Best VM Loads for instance_9_40_10_2.txt : [23. 35. 30. 35. 34. 29.  5. 30. 35. 20.]
# Computed Best Makespan (max VM load): 35.0
# Total Task Execution Time for instance_9_40_10_2.txt: 2996.0
#
# Best VM Loads for instance_4_20_10_4.txt : [16.  5. 16. 16. 14. 15.  6. 12.  7. 13.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_4_20_10_4.txt: 1464.0
#
# Best VM Loads for instance_3_10_10_9.txt : [12. 10. 10.  7.  5.  0.  6.  6.  0. 12.]
# Computed Best Makespan (max VM load): 12.0
# Total Task Execution Time for instance_3_10_10_9.txt: 746.0
#
# Best VM Loads for instance_2_10_10_1.txt : [ 0.  0.  7.  5.  6.  5. 12.  0. 12. 12.]
# Computed Best Makespan (max VM load): 12.0
# Total Task Execution Time for instance_2_10_10_1.txt: 731.0
#
# Best VM Loads for instance_10_70_10_2.txt : [48. 43. 46. 41. 47. 44. 47. 43. 44. 46.]
# Computed Best Makespan (max VM load): 48.0
# Total Task Execution Time for instance_10_70_10_2.txt: 5260.0
#
# Best VM Loads for instance_10_20_10_12.txt : [10. 15. 12. 15. 15. 17. 11.  0. 16. 17.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_10_20_10_12.txt: 1528.0
#
# Best VM Loads for instance_7_10_10_5.txt : [14.  8.  5.  7. 14.  9.  7.  0.  8.  0.]
# Computed Best Makespan (max VM load): 14.0
# Total Task Execution Time for instance_7_10_10_5.txt: 758.0
#
# Best VM Loads for instance_10_70_10_10.txt : [48. 52. 38. 55. 55. 51. 44. 53. 47. 45.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_10_70_10_10.txt: 5259.0
#
# Best VM Loads for instance_7_10_10_14.txt : [ 0.  5. 10.  5.  5.  0.  0. 11. 11.  6.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_7_10_10_14.txt: 757.0
#
# Best VM Loads for instance_9_30_10_3.txt : [26. 17. 18. 26. 10. 18. 13. 20. 26. 21.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_9_30_10_3.txt: 2243.0
#
# Best VM Loads for instance_1_70_10_9.txt : [48. 44. 35. 49. 47. 46. 48. 49. 49. 45.]
# Computed Best Makespan (max VM load): 49.0
# Total Task Execution Time for instance_1_70_10_9.txt: 5255.0
#
# Best VM Loads for instance_10_100_10_6.txt : [76. 43. 77. 64. 75. 69. 65. 68. 76. 73.]
# Computed Best Makespan (max VM load): 77.0
# Total Task Execution Time for instance_10_100_10_6.txt: 7484.0
#
# Best VM Loads for instance_4_70_10_8.txt : [54. 56. 50. 26. 40. 56. 56. 25. 54. 45.]
# Computed Best Makespan (max VM load): 56.0
# Total Task Execution Time for instance_4_70_10_8.txt: 5214.0
#
# Best VM Loads for instance_9_40_10_20.txt : [34. 22. 24. 34. 24. 23. 12. 34. 28. 20.]
# Computed Best Makespan (max VM load): 34.0
# Total Task Execution Time for instance_9_40_10_20.txt: 3014.0
#
# Best VM Loads for instance_2_10_10_3.txt : [ 0.  6.  8.  6. 11.  6. 10.  6.  5.  7.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_2_10_10_3.txt: 736.0
#
# Best VM Loads for instance_7_90_10_18.txt : [68. 66. 64. 65. 41. 57. 64. 69. 60. 69.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_7_90_10_18.txt: 6857.0
#
# Best VM Loads for instance_4_100_10_8.txt : [61. 66. 66. 64. 65. 66. 69. 63. 65. 69.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_4_100_10_8.txt: 7424.0
#
# Best VM Loads for instance_2_10_10_20.txt : [11.  7.  9.  7.  9.  7.  8.  7.  9.  0.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_2_10_10_20.txt: 755.0
#
# Best VM Loads for instance_7_90_10_7.txt : [62. 61. 51. 58. 52. 56. 55. 61. 62. 50.]
# Computed Best Makespan (max VM load): 62.0
# Total Task Execution Time for instance_7_90_10_7.txt: 6647.0
#
# Best VM Loads for instance_9_90_10_15.txt : [48. 63. 71. 65. 71. 70. 67. 66. 51. 69.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_9_90_10_15.txt: 6744.0
#
# Best VM Loads for instance_5_30_10_4.txt : [21. 18. 23. 19. 14. 20. 18. 23. 23. 16.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_5_30_10_4.txt: 2268.0
#
# Best VM Loads for instance_9_80_10_5.txt : [57. 51. 53. 57. 45. 44. 55. 57. 57. 43.]
# Computed Best Makespan (max VM load): 57.0
# Total Task Execution Time for instance_9_80_10_5.txt: 6068.0
#
# Best VM Loads for instance_5_80_10_8.txt : [56. 60. 49. 61. 60. 64. 62. 52. 57. 64.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_5_80_10_8.txt: 6121.0
#
# Best VM Loads for instance_2_20_10_1.txt : [ 7. 14. 13. 12. 15. 13. 17. 16. 15. 15.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_2_20_10_1.txt: 1503.0
#
# Best VM Loads for instance_3_80_10_9.txt : [61. 47. 61. 61. 61. 50. 54. 52. 56. 52.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_3_80_10_9.txt: 6098.0
#
# Best VM Loads for instance_9_60_10_1.txt : [44. 34. 41. 37. 37. 34. 44. 33. 41. 42.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_9_60_10_1.txt: 4440.0
#
# Best VM Loads for instance_7_80_10_3.txt : [39. 47. 52. 54. 52. 50. 58. 53. 59. 59.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_7_80_10_3.txt: 5975.0
#
# Best VM Loads for instance_5_50_10_13.txt : [31. 37. 36. 26. 31. 34. 30. 37. 27. 33.]
# Computed Best Makespan (max VM load): 37.0
# Total Task Execution Time for instance_5_50_10_13.txt: 3784.0
#
# Best VM Loads for instance_10_90_10_2.txt : [59. 59. 60. 59. 48. 67. 67. 53. 66. 59.]
# Computed Best Makespan (max VM load): 67.0
# Total Task Execution Time for instance_10_90_10_2.txt: 6720.0
#
# Best VM Loads for instance_7_70_10_7.txt : [52. 52. 53. 53. 24. 50. 48. 48. 54. 53.]
# Computed Best Makespan (max VM load): 54.0
# Total Task Execution Time for instance_7_70_10_7.txt: 5344.0
#
# Best VM Loads for instance_10_100_10_17.txt : [77. 77. 60. 72. 73. 63. 61. 55. 72. 71.]
# Computed Best Makespan (max VM load): 77.0
# Total Task Execution Time for instance_10_100_10_17.txt: 7541.0
#
# Best VM Loads for instance_9_70_10_14.txt : [52. 45. 55. 53. 37. 54. 55. 41. 50. 38.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_9_70_10_14.txt: 5264.0
#
# Best VM Loads for instance_4_20_10_1.txt : [14. 13.  7. 19. 19. 18. 17. 19. 10. 18.]
# Computed Best Makespan (max VM load): 19.0
# Total Task Execution Time for instance_4_20_10_1.txt: 1523.0
#
# Best VM Loads for instance_6_20_10_11.txt : [ 5. 18.  5. 14.  9. 17. 17. 13. 18. 13.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_6_20_10_11.txt: 1469.0
#
# Best VM Loads for instance_7_50_10_13.txt : [36. 29. 36. 42. 42. 42. 22. 23. 37. 41.]
# Computed Best Makespan (max VM load): 42.0
# Total Task Execution Time for instance_7_50_10_13.txt: 3736.0
#
# Best VM Loads for instance_8_40_10_4.txt : [29. 30. 24. 30. 14. 31. 30. 31. 26. 31.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_8_40_10_4.txt: 3002.0
#
# Best VM Loads for instance_4_50_10_12.txt : [31. 31. 32. 34. 35. 36. 35. 32. 35. 20.]
# Computed Best Makespan (max VM load): 36.0
# Total Task Execution Time for instance_4_50_10_12.txt: 3779.0
#
# Best VM Loads for instance_8_90_10_7.txt : [56. 63. 58. 55. 54. 54. 57. 62. 61. 63.]
# Computed Best Makespan (max VM load): 63.0
# Total Task Execution Time for instance_8_90_10_7.txt: 6678.0
#
# Best VM Loads for instance_2_100_10_7.txt : [56. 45. 72. 76. 69. 65. 76. 69. 67. 73.]
# Computed Best Makespan (max VM load): 76.0
# Total Task Execution Time for instance_2_100_10_7.txt: 7415.0
#
# Best VM Loads for instance_7_70_10_6.txt : [46. 52. 50. 30. 50. 52. 50. 40. 51. 41.]
# ...
#
# Best VM Loads for instance_7_60_10_7.txt : [45. 42. 39. 47. 47. 40. 43. 46. 36. 32.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_7_60_10_7.txt: 4514.0
#
# Best VM Loads for instance_3_30_10_12.txt : [29. 25. 27. 10. 12. 24. 29. 29.  5. 10.]
# Computed Best Makespan (max VM load): 29.0
# Total Task Execution Time for instance_3_30_10_12.txt: 2308.0
#
# Best VM Loads for instance_8_100_10_12.txt : [70. 63. 69. 61. 60. 65. 68. 66. 66. 70.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_8_100_10_12.txt: 7436.0
#
# Best VM Loads for instance_6_10_10_19.txt : [ 8.  6.  6.  6.  5.  7. 10.  6.  5. 10.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_6_10_10_19.txt: 762.0
#
# Best VM Loads for instance_7_40_10_15.txt : [21. 26. 22. 23. 28. 24. 26. 23. 24. 24.]
# Computed Best Makespan (max VM load): 28.0
# Total Task Execution Time for instance_7_40_10_15.txt: 3059.0
#
# Best VM Loads for instance_6_90_10_1.txt : [56. 66. 35. 56. 58. 66. 61. 60. 66. 59.]
# Computed Best Makespan (max VM load): 66.0
# Total Task Execution Time for instance_6_90_10_1.txt: 6671.0
#
# Best VM Loads for instance_10_70_10_9.txt : [51. 49. 52. 44. 31. 54. 53. 45. 50. 52.]
# Computed Best Makespan (max VM load): 54.0
# Total Task Execution Time for instance_10_70_10_9.txt: 5258.0
#
# Best VM Loads for instance_1_100_10_13.txt : [67. 69. 69. 66. 69. 66. 72. 64. 71. 67.]
# Computed Best Makespan (max VM load): 72.0
# Total Task Execution Time for instance_1_100_10_13.txt: 7586.0
#
# Best VM Loads for instance_1_30_10_17.txt : [26. 22.  5. 24. 21. 12. 18. 19. 26. 20.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_1_30_10_17.txt: 2274.0
#
# Best VM Loads for instance_2_30_10_9.txt : [20. 24. 16. 22. 24. 15. 23. 24. 27. 23.]
# Computed Best Makespan (max VM load): 27.0
# Total Task Execution Time for instance_2_30_10_9.txt: 2252.0
#
# Best VM Loads for instance_7_50_10_19.txt : [28. 32. 35. 34. 33. 31. 28. 35. 34. 35.]
# Computed Best Makespan (max VM load): 35.0
# Total Task Execution Time for instance_7_50_10_19.txt: 3707.0
#
# Best VM Loads for instance_3_80_10_16.txt : [32. 51. 56. 58. 54. 58. 55. 60. 53. 58.]
# Computed Best Makespan (max VM load): 60.0
# Total Task Execution Time for instance_3_80_10_16.txt: 6034.0
#
# Best VM Loads for instance_6_10_10_13.txt : [ 0.  5. 10. 10.  5.  5.  6.  5.  5.  5.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_6_10_10_13.txt: 718.0
#
# Best VM Loads for instance_3_10_10_2.txt : [ 0.  7. 11.  7. 11.  7.  5.  0.  6.  8.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_3_10_10_2.txt: 736.0
#
# Best VM Loads for instance_2_30_10_2.txt : [24. 22. 18. 24. 22. 24. 17.  5. 23. 16.]
# Computed Best Makespan (max VM load): 24.0
# Total Task Execution Time for instance_2_30_10_2.txt: 2265.0
#
# Best VM Loads for instance_3_60_10_20.txt : [31. 40. 46. 38. 45. 37. 46. 47. 42. 40.]
# Computed Best Makespan (max VM load): 47.0
# Total Task Execution Time for instance_3_60_10_20.txt: 4526.0
#
# Best VM Loads for instance_10_60_10_4.txt : [45. 29. 35. 45. 43. 41. 43. 40. 45. 38.]
# Computed Best Makespan (max VM load): 45.0
# Total Task Execution Time for instance_10_60_10_4.txt: 4527.0
#
# Best VM Loads for instance_8_100_10_14.txt : [65. 65. 68. 71. 71. 64. 71. 65. 68. 66.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_8_100_10_14.txt: 7522.0
#
# Best VM Loads for instance_9_100_10_9.txt : [62. 72. 68. 55. 72. 69. 55. 72. 72. 63.]
# Computed Best Makespan (max VM load): 72.0
# Total Task Execution Time for instance_9_100_10_9.txt: 7496.0
#
# Best VM Loads for instance_9_20_10_19.txt : [14. 16. 15. 10. 10. 11. 12. 10. 14. 13.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_9_20_10_19.txt: 1488.0
#
# Best VM Loads for instance_1_60_10_11.txt : [17. 48. 43. 48. 43. 30. 40. 26. 39. 46.]
# Computed Best Makespan (max VM load): 48.0
# Total Task Execution Time for instance_1_60_10_11.txt: 4491.0
#
# Best VM Loads for instance_1_20_10_5.txt : [16. 12. 13. 10. 11.  6. 16. 11. 14. 14.]
# Computed Best Makespan (max VM load): 16.0
# Total Task Execution Time for instance_1_20_10_5.txt: 1472.0
#
# Best VM Loads for instance_3_20_10_2.txt : [12. 11. 17.  9. 16. 18.  6. 18.  0. 15.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_3_20_10_2.txt: 1489.0
#
# Best VM Loads for instance_10_30_10_11.txt : [20. 23. 20. 20. 22. 21. 22. 20. 19. 18.]
# Computed Best Makespan (max VM load): 23.0
# Total Task Execution Time for instance_10_30_10_11.txt: 2234.0
#
# Best VM Loads for instance_5_40_10_11.txt : [33. 30. 18. 32. 22. 32. 10. 33. 19. 32.]
# Computed Best Makespan (max VM load): 33.0
# Total Task Execution Time for instance_5_40_10_11.txt: 3026.0
#
# Best VM Loads for instance_9_90_10_10.txt : [68. 60. 43. 63. 68. 55. 61. 66. 53. 67.]
# Computed Best Makespan (max VM load): 68.0
# Total Task Execution Time for instance_9_90_10_10.txt: 6708.0
#
# Best VM Loads for instance_10_40_10_12.txt : [31. 19. 31. 25. 31. 26. 31. 31. 29. 19.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_10_40_10_12.txt: 3001.0
#
# Best VM Loads for instance_7_40_10_13.txt : [20. 28. 34. 23. 21. 29. 23. 34. 12. 34.]
# Computed Best Makespan (max VM load): 34.0
# Total Task Execution Time for instance_7_40_10_13.txt: 2955.0
#
# Best VM Loads for instance_3_50_10_20.txt : [26. 19. 38. 38. 37. 34. 34. 37. 29. 35.]
# Computed Best Makespan (max VM load): 38.0
# Total Task Execution Time for instance_3_50_10_20.txt: 3735.0
#
# Best VM Loads for instance_6_80_10_10.txt : [49. 50. 59. 52. 54. 56. 51. 57. 43. 59.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_6_80_10_10.txt: 5983.0
#
# Best VM Loads for instance_10_80_10_7.txt : [57. 52. 48. 53. 55. 57. 46. 55. 54. 51.]
# Computed Best Makespan (max VM load): 57.0
# Total Task Execution Time for instance_10_80_10_7.txt: 5987.0
#
# Best VM Loads for instance_9_60_10_3.txt : [29. 34. 39. 36. 43. 43. 37. 43. 42. 40.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_9_60_10_3.txt: 4476.0
#
# Best VM Loads for instance_2_20_10_2.txt : [ 6. 17. 17. 13. 15.  6. 16. 16. 16. 18.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_2_20_10_2.txt: 1499.0
#
# Best VM Loads for instance_3_60_10_10.txt : [44. 42. 38. 39. 43. 29. 29. 41. 43. 44.]
# Computed Best Makespan (max VM load): 44.0
# Total Task Execution Time for instance_3_60_10_10.txt: 4482.0
#
# Best VM Loads for instance_7_90_10_13.txt : [52. 60. 40. 62. 63. 54. 64. 63. 57. 63.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_7_90_10_13.txt: 6714.0
#
# Best VM Loads for instance_1_80_10_6.txt : [58. 49. 47. 47. 46. 55. 58. 53. 58. 57.]
# Computed Best Makespan (max VM load): 58.0
# Total Task Execution Time for instance_1_80_10_6.txt: 5962.0
#
# Best VM Loads for instance_6_90_10_19.txt : [60. 64. 61. 64. 65. 59. 61. 64. 66. 66.]
# Computed Best Makespan (max VM load): 66.0
# Total Task Execution Time for instance_6_90_10_19.txt: 6728.0
#
# Best VM Loads for instance_9_30_10_8.txt : [25. 25. 19. 15. 23. 16. 19. 19. 24. 20.]
# Computed Best Makespan (max VM load): 25.0
# Total Task Execution Time for instance_9_30_10_8.txt: 2270.0
#
# Best VM Loads for instance_1_90_10_19.txt : [64. 61. 64. 59. 59. 55. 59. 63. 57. 51.]
# Computed Best Makespan (max VM load): 64.0
# Total Task Execution Time for instance_1_90_10_19.txt: 6794.0
#
# Best VM Loads for instance_5_70_10_20.txt : [51. 53. 51. 56. 53. 50. 54. 46. 54. 40.]
# Computed Best Makespan (max VM load): 56.0
# Total Task Execution Time for instance_5_70_10_20.txt: 5361.0
#
# Best VM Loads for instance_7_60_10_3.txt : [33. 42. 41. 46. 33. 39. 35. 39. 46. 38.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_7_60_10_3.txt: 4463.0
#
# Best VM Loads for instance_5_70_10_16.txt : [39. 40. 54. 50. 54. 38. 55. 52. 55. 47.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_5_70_10_16.txt: 5326.0
#
# Best VM Loads for instance_3_80_10_20.txt : [56. 55. 51. 48. 58. 51. 45. 44. 58. 53.]
# Computed Best Makespan (max VM load): 58.0
# Total Task Execution Time for instance_3_80_10_20.txt: 5940.0
#
# Best VM Loads for instance_6_70_10_11.txt : [26. 53. 53. 41. 48. 55. 55. 51. 54. 46.]
# Computed Best Makespan (max VM load): 55.0
# Total Task Execution Time for instance_6_70_10_11.txt: 5242.0
#
# Best VM Loads for instance_5_90_10_14.txt : [58. 66. 69. 59. 56. 45. 53. 62. 65. 69.]
# Computed Best Makespan (max VM load): 69.0
# Total Task Execution Time for instance_5_90_10_14.txt: 6722.0
#
# Best VM Loads for instance_1_30_10_11.txt : [24. 25. 24. 25. 15. 26.  0. 24. 26. 21.]
# Computed Best Makespan (max VM load): 26.0
# Total Task Execution Time for instance_1_30_10_11.txt: 2247.0
#
# Best VM Loads for instance_1_60_10_15.txt : [39. 39. 36. 38. 39. 43. 34. 32. 40. 30.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_1_60_10_15.txt: 4454.0
#
# Best VM Loads for instance_6_10_10_6.txt : [ 7.  8.  7.  5.  6.  7.  0.  5. 10.  8.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_6_10_10_6.txt: 732.0
#
# Best VM Loads for instance_5_10_10_17.txt : [ 0.  8.  5.  0.  5.  6. 10.  7. 10.  5.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_5_10_10_17.txt: 762.0
#
# Best VM Loads for instance_8_70_10_2.txt : [47. 51. 44. 38. 53. 49. 49. 48. 43. 53.]
# Computed Best Makespan (max VM load): 53.0
# Total Task Execution Time for instance_8_70_10_2.txt: 5322.0
#
# Best VM Loads for instance_9_90_10_8.txt : [57. 46. 61. 58. 60. 45. 58. 62. 59. 62.]
# Computed Best Makespan (max VM load): 62.0
# Total Task Execution Time for instance_9_90_10_8.txt: 6746.0
#
# Best VM Loads for instance_8_40_10_10.txt : [25. 23. 32. 29. 21. 27. 24. 24. 24. 32.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_8_40_10_10.txt: 2985.0
#
# Best VM Loads for instance_1_40_10_18.txt : [20. 20. 32. 30. 25. 32. 12. 20. 31. 25.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_1_40_10_18.txt: 2988.0
#
# Best VM Loads for instance_6_100_10_15.txt : [67. 67. 71. 61. 66. 64. 55. 69. 67. 68.]
# Computed Best Makespan (max VM load): 71.0
# Total Task Execution Time for instance_6_100_10_15.txt: 7520.0
#
# Best VM Loads for instance_1_20_10_1.txt : [ 9. 13. 11. 13.  6. 18. 14. 14. 18. 15.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_1_20_10_1.txt: 1506.0
#
# Best VM Loads for instance_1_10_10_4.txt : [ 0.  6. 11.  0. 11.  0.  5. 11. 10.  9.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_1_10_10_4.txt: 757.0
#
# Best VM Loads for instance_5_50_10_10.txt : [29. 31. 34. 35. 39. 37. 38. 38. 31. 38.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_5_50_10_10.txt: 3753.0
#
# Best VM Loads for instance_5_100_10_6.txt : [69. 66. 70. 70. 52. 59. 63. 68. 69. 70.]
# Computed Best Makespan (max VM load): 70.0
# Total Task Execution Time for instance_5_100_10_6.txt: 7442.0
#
# Best VM Loads for instance_6_40_10_17.txt : [28. 31. 22. 33.  5. 28. 33. 26. 27. 21.]
# Computed Best Makespan (max VM load): 33.0
# Total Task Execution Time for instance_6_40_10_17.txt: 3040.0
#
# Best VM Loads for instance_3_100_10_19.txt : [69. 71. 69. 70. 61. 75. 74. 74. 75. 65.]
# Computed Best Makespan (max VM load): 75.0
# Total Task Execution Time for instance_3_100_10_19.txt: 7555.0
#
# Best VM Loads for instance_4_50_10_7.txt : [26. 39. 33. 30. 32. 16. 36. 38. 39. 34.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_4_50_10_7.txt: 3767.0
#
# Best VM Loads for instance_1_70_10_2.txt : [54. 53. 52. 45. 47. 52. 48. 46. 42. 48.]
# Computed Best Makespan (max VM load): 54.0
# Total Task Execution Time for instance_1_70_10_2.txt: 5276.0
#
# Best VM Loads for instance_1_40_10_14.txt : [29. 32. 29. 29. 26. 27. 14. 25. 30. 20.]
# Computed Best Makespan (max VM load): 32.0
# Total Task Execution Time for instance_1_40_10_14.txt: 3016.0
#
# Best VM Loads for instance_7_10_10_17.txt : [ 6. 11.  7.  5.  7.  8.  8.  8.  0.  8.]
# Computed Best Makespan (max VM load): 11.0
# Total Task Execution Time for instance_7_10_10_17.txt: 746.0
#
# Best VM Loads for instance_1_40_10_6.txt : [20. 25. 28. 31. 18. 28. 30. 25. 29. 26.]
# Computed Best Makespan (max VM load): 31.0
# Total Task Execution Time for instance_1_40_10_6.txt: 2985.0
#
# Best VM Loads for instance_5_80_10_15.txt : [47. 54. 55. 57. 58. 36. 55. 60. 61. 59.]
# Computed Best Makespan (max VM load): 61.0
# Total Task Execution Time for instance_5_80_10_15.txt: 6020.0
#
# Best VM Loads for instance_2_80_10_15.txt : [57. 53. 51. 53. 59. 55. 44. 46. 59. 52.]
# Computed Best Makespan (max VM load): 59.0
# Total Task Execution Time for instance_2_80_10_15.txt: 5935.0
#
# Best VM Loads for instance_4_60_10_8.txt : [34. 41. 34. 36. 43. 43. 31. 39. 33. 42.]
# Computed Best Makespan (max VM load): 43.0
# Total Task Execution Time for instance_4_60_10_8.txt: 4503.0
#
# Best VM Loads for instance_7_70_10_11.txt : [44. 50. 46. 47. 48. 44. 43. 39. 51. 49.]
# Computed Best Makespan (max VM load): 51.0
# Total Task Execution Time for instance_7_70_10_11.txt: 5269.0
#
# Best VM Loads for instance_2_10_10_12.txt : [ 7.  8.  6.  7.  5.  7.  6. 10. 10.  9.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_2_10_10_12.txt: 763.0
#
# Best VM Loads for instance_4_70_10_2.txt : [57. 50. 31. 54. 45. 50. 54. 53. 52. 52.]
# Computed Best Makespan (max VM load): 57.0
# Total Task Execution Time for instance_4_70_10_2.txt: 5324.0
#
# Best VM Loads for instance_3_60_10_8.txt : [44. 41. 46. 41. 38. 46. 33. 46. 42. 22.]
# Computed Best Makespan (max VM load): 46.0
# Total Task Execution Time for instance_3_60_10_8.txt: 4535.0
#
# Best VM Loads for instance_8_50_10_20.txt : [39. 32. 39. 37. 39. 25. 23. 33. 37. 34.]
# Computed Best Makespan (max VM load): 39.0
# Total Task Execution Time for instance_8_50_10_20.txt: 3786.0
#
# Best VM Loads for instance_7_10_10_11.txt : [10.  9. 10. 10.  8. 10.  0.  5.  8.  5.]
# Computed Best Makespan (max VM load): 10.0
# Total Task Execution Time for instance_7_10_10_11.txt: 752.0
#
# Best VM Loads for instance_4_20_10_2.txt : [18. 18.  5.  5. 15. 18. 10. 16. 18.  5.]
# Computed Best Makespan (max VM load): 18.0
# Total Task Execution Time for instance_4_20_10_2.txt: 1515.0
#
# Best VM Loads for instance_3_20_10_6.txt : [16. 15. 15. 12. 17.  6.  7. 17. 17. 11.]
# Computed Best Makespan (max VM load): 17.0
# Total Task Execution Time for instance_3_20_10_6.txt: 1462.0
#                        dataset  num_tasks  best_makespan  worst_makespan  \
# 0      instance_4_90_10_10.txt         90           66.0            66.0
# 1      instance_2_90_10_14.txt         90           64.0            64.0
# 2      instance_10_70_10_3.txt         70           49.0            49.0
# 3       instance_2_50_10_2.txt         50           41.0            41.0
# 4     instance_10_80_10_11.txt         80           60.0            60.0
# ...                        ...        ...            ...             ...
# 1995    instance_3_60_10_8.txt         60           46.0            46.0
# 1996   instance_8_50_10_20.txt         50           39.0            39.0
# 1997   instance_7_10_10_11.txt         10           10.0            10.0
# 1998    instance_4_20_10_2.txt         20           18.0            18.0
# 1999    instance_3_20_10_6.txt         20           17.0            17.0
#
#       avg_makespan  degree_of_imbalance
# 0             66.0             1.800327
# 1             64.0             1.959459
# 2             49.0             1.995516
# 3             41.0             1.637427
# 4             60.0             1.883239
# ...            ...                  ...
# 1995          46.0             1.704261
# 1996          39.0             1.834320
# 1997          10.0             1.333333
# 1998          18.0             1.796875
# 1999          17.0             1.729323
#
# [2000 rows x 6 columns]

# %%
# Find the Best Result from the Results List

# Find the dataset with the minimum (best) makespan
best_index = df_results["best_makespan"].idxmin()
best_result = df_results.loc[best_index]

# Print the best result
print("Best Result Found:")
print(best_result)
# Out:
# Best Result Found:
# dataset                instance_6_10_10_14.txt
# num_tasks                                   10
# best_makespan                              7.0
# worst_makespan                             7.0
# avg_makespan                               7.0
# degree_of_imbalance                   1.969697
# Name: 1795, dtype: object

# %%
import matplotlib.pyplot as plt

#  Plot Best Makespan vs. Number of Tasks
plt.figure(figsize=(12, 6))
plt.bar(df_results["num_tasks"], df_results["best_makespan"], color='g', label="Best Makespan", width=5)
plt.xlabel("Number of Tasks")
plt.ylabel("Best Makespan")
plt.title("Best Makespan vs. Number of Tasks")
plt.xticks(ticks=range(10, 110, 10))  # Ensure x-axis shows 10, 20, ..., 100
plt.legend()
plt.grid()
plt.show()

#  Plot Worst Makespan vs. Number of Tasks
plt.figure(figsize=(12, 6))
plt.bar(df_results["num_tasks"], df_results["worst_makespan"], color='r', label="Worst Makespan", width=5)
plt.xlabel("Number of Tasks")
plt.ylabel("Worst Makespan")
plt.title("Worst Makespan vs. Number of Tasks")
plt.xticks(ticks=range(10, 110, 10))
plt.legend()
plt.grid()
plt.show()

#  Plot Average Makespan vs. Number of Tasks
plt.figure(figsize=(12, 6))
plt.bar(df_results["num_tasks"], df_results["avg_makespan"],  color='b', label="Avg Makespan", width=5)
plt.xlabel("Number of Tasks")
plt.ylabel("Average Makespan")
plt.title("Average Makespan vs. Number of Tasks")
plt.xticks(ticks=range(10, 110, 10))
plt.legend()
plt.grid()
plt.show()

#  Plot Balance Factor vs. Number of Tasks
plt.figure(figsize=(12, 6))
plt.bar(df_results["num_tasks"], df_results["degree_of_imbalance"], color='m', label="Degree Of Imbalance", width=5)
plt.xlabel("Number of Tasks")
plt.ylabel("Balance Factor")
plt.title("Degree Of Imbalance vs. Number of Tasks")
plt.xticks(ticks=range(10, 110, 10))  # Ensure x-axis shows 10, 20, ..., 100
plt.legend()
plt.grid(axis='y')
plt.show()

#  Display updated results table
display(df_results)
# Out:
#                        dataset  num_tasks  best_makespan  worst_makespan  \
# 0      instance_4_90_10_10.txt         90           66.0            66.0
# 1      instance_2_90_10_14.txt         90           64.0            64.0
# 2      instance_10_70_10_3.txt         70           49.0            49.0
# 3       instance_2_50_10_2.txt         50           41.0            41.0
# 4     instance_10_80_10_11.txt         80           60.0            60.0
# ...                        ...        ...            ...             ...
# 1995    instance_3_60_10_8.txt         60           46.0            46.0
# 1996   instance_8_50_10_20.txt         50           39.0            39.0
# 1997   instance_7_10_10_11.txt         10           10.0            10.0
# 1998    instance_4_20_10_2.txt         20           18.0            18.0
# 1999    instance_3_20_10_6.txt         20           17.0            17.0
#
#       avg_makespan  degree_of_imbalance
# 0             66.0             1.800327
# 1             64.0             1.959459
# 2             49.0             1.995516
# 3             41.0             1.637427
# 4             60.0             1.883239
# ...            ...                  ...
# 1995          46.0             1.704261
# 1996          39.0             1.834320
# 1997          10.0             1.333333
# 1998          18.0             1.796875
# 1999          17.0             1.729323
#
# [2000 rows x 6 columns]
